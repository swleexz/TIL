# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_node(1)
print(G.nodes())
# Out:
# [1]

# %%
G.add_node('P')
G.add_node('Hi')
print(G.nodes())
# Out:
# [1, 'P', 'Hi']

# %%
G.add_nodes_from([2, 3])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3]

# %%
for node in G.nodes():
    print(node)
# Out:
# 1
# P
# Hi
# 2
# 3

# %%
G.add_nodes_from([3, 4])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]

# %%
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
G.add_edge(1, 2)
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='grey')

# %%
print(G.edges())
# Out:
# [(1, 2)]

# %%
G.add_edge(4, 5)
print(G.edges())
# Out:
# [(1, 2), (4, 5)]

# %%
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5)])
print(G.edges())
# Out:
# [(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)]

# %%
G.add_edges_from([(1, 'Hi'), (1, 'P')])
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %%
G = nx.path_graph(4)
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='grey')

# %%
G = nx.Graph()
nx.add_path(G, [0, 1, 2, 3])
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='grey')

# %%
G = nx.Graph()
nx.add_path(G, [0, 1, 2, 3])
print(G.degree(0))
print(G.degree([0, 1]))
print(G.degree())
# Out:
# 1
# [(0, 1), (1, 2)]
# [(0, 1), (1, 2), (2, 2), (3, 1)]

# %%
print(G.edges())
G.remove_edge(1, 2)
print(G.edges())
# Out:
# [(0, 1), (1, 2), (2, 3)]
# [(0, 1), (2, 3)]

# %%
print(G.edges())
G.remove_edges_from([(0, 1), (2, 3)])
print(G.edges())
# Out:
# [(0, 1), (2, 3)]
# []

# %%
print(G.nodes())
G.remove_node(2)
print(G.nodes())
# Out:
# [0, 1, 2, 3]
# [0, 1, 3]

# %%
print(G.nodes())
G.remove_nodes_from([0, 1, 3])
print(G.nodes())
# Out:
# [0, 1, 3]
# []

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)])
print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
# Out:
# number of nodes: 5
# number of edges: 5

# %%
G.remove_edge(1, 3)
print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
# Out:
# number of nodes: 5
# number of edges: 4

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)])
print(G.edges())
G.remove_edge(1, 3)
print(G.edges())
print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
# Out:
# [(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)]
# [(1, 2), (1, 4), (1, 5), (4, 5)]
# number of nodes: 5
# number of edges: 4

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)])
nx.draw(G, with_labels=True)
print(G.nodes())
G.remove_node(3)
print(G.nodes())
print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 4, 5]
# number of nodes: 4
# number of edges: 4

# %%
nx.draw(G, with_labels=True)

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)])
nx.draw(G, with_labels=True)
print(G.nodes())
G.remove_node(4)
print(G.nodes())
print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 5]
# number of nodes: 4
# number of edges: 3

# %%
nx.draw(G, with_labels=True)

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)])
nx.draw(G, with_labels=True)
print(G.nodes())
G.remove_nodes_from([4, 5])
print(G.nodes())
print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3]
# number of nodes: 3
# number of edges: 2

# %%
nx.draw(G, with_labels=True)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.erdos_renyi_graph(25, 0.2)
nx.draw(G)

# %%
G = nx.watts_strogatz_graph(30, 3, 0.1)
nx.draw(G)

# %%
G = nx.barabasi_albert_graph(25, 5)
nx.draw(G)

# %%
G = nx.random_lobster(25, 0.9, 0.9)
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\YWIS\Desktop\TIL\01_bigdata_ai_via_python\06_01_bigdata_analysis.ipynb Cell 34' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/YWIS/Desktop/TIL/01_bigdata_ai_via_python/06_01_bigdata_analysis.ipynb#ch0000033?line=0'>1</a> G = nx.random_lobster(25, 0.9, 0.9)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/YWIS/Desktop/TIL/01_bigdata_ai_via_python/06_01_bigdata_analysis.ipynb#ch0000033?line=1'>2</a> nx.draw(G)
#
# File c:\Users\YWIS\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:120, in draw(G, pos, ax, **kwds)
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=116'>117</a> if "with_labels" not in kwds:
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=117'>118</a>     kwds["with_labels"] = "labels" in kwds
# --> <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=119'>120</a> draw_networkx(G, pos=pos, ax=ax, **kwds)
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=120'>121</a> ax.set_axis_off()
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=121'>122</a> plt.draw_if_interactive()
#
# File c:\Users\YWIS\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:331, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=327'>328</a> label_kwds = {k: v for k, v in kwds.items() if k in valid_label_kwds}
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=329'>330</a> if pos is None:
# --> <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=330'>331</a>     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=332'>333</a> draw_networkx_nodes(G, pos, **node_kwds)
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/nx_pylab.py?line=333'>334</a> draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:4, in argmap_spring_layout_1(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       <a href='file:///%3Cclass%20%27networkx.utils.decorators.argmap%27%3E%20compilation%204?line=1'>2</a> from os.path import splitext
#       <a href='file:///%3Cclass%20%27networkx.utils.decorators.argmap%27%3E%20compilation%204?line=2'>3</a> from contextlib import contextmanager
# ----> <a href='file:///%3Cclass%20%27networkx.utils.decorators.argmap%27%3E%20compilation%204?line=3'>4</a> from pathlib import Path
#       <a href='file:///%3Cclass%20%27networkx.utils.decorators.argmap%27%3E%20compilation%204?line=5'>6</a> import networkx as nx
#       <a href='file:///%3Cclass%20%27networkx.utils.decorators.argmap%27%3E%20compilation%204?line=6'>7</a> from networkx.utils import create_random_state, create_py_random_state
#
# File c:\Users\YWIS\anaconda3\lib\site-packages\networkx\drawing\layout.py:476, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/layout.py?line=473'>474</a> if len(G) < 500:  # sparse solver for large graphs
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/layout.py?line=474'>475</a>     raise ValueError
# --> <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/layout.py?line=475'>476</a> A = nx.to_scipy_sparse_array(G, weight=weight, dtype="f")
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/layout.py?line=476'>477</a> if k is None and fixed is not None:
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/layout.py?line=477'>478</a>     # We must adjust k by domain size for layouts not near 1x1
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/drawing/layout.py?line=478'>479</a>     nnodes, _ = A.shape
#
# File c:\Users\YWIS\anaconda3\lib\site-packages\networkx\convert_matrix.py:921, in to_scipy_sparse_array(G, nodelist, dtype, weight, format)
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/convert_matrix.py?line=918'>919</a>         r += diag_index
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/convert_matrix.py?line=919'>920</a>         c += diag_index
# --> <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/convert_matrix.py?line=920'>921</a>     A = sp.sparse.coo_array((d, (r, c)), shape=(nlen, nlen), dtype=dtype)
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/convert_matrix.py?line=921'>922</a> try:
#     <a href='file:///c%3A/Users/YWIS/anaconda3/lib/site-packages/networkx/convert_matrix.py?line=922'>923</a>     return A.asformat(format)
#
# AttributeError: module 'scipy.sparse' has no attribute 'coo_array'

# %%
from scipy.stats import bernoulli

for i in range(6):
    print(bernoulli.rvs(p=0.33))
# Out:
# 1
# 0
# 1
# 1
# 1
# 0

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.stats import bernoulli

# %%
def erdos_graph(N, p):
    G = nx.Graph()
    G.add_nodes_from(range(N))
    list_G = list(G.nodes())
    for i, node1 in enumerate(list_G):
        for node2 in list_G[i+1:]:
            if bernoulli.rvs(p=p):
                G.add_edge(node1, node2)

    return G


nx.draw(erdos_graph(20, 0.18))

# %%
G1= erdos_graph(80, 0.3)
plt.hist(list([d for n, d in G1.degree()]), histtype='step')
# Out:
# (array([ 2.,  5., 11.,  8., 14., 12.,  3., 14.,  7.,  4.]),
#  array([14. , 15.7, 17.4, 19.1, 20.8, 22.5, 24.2, 25.9, 27.6, 29.3, 31. ]),
#  [<matplotlib.patches.Polygon at 0x2938c97b3d0>])

# %%
def plt_graph(G):
    plt.hist(list([d for n, d in G.degree()]), histtype='step')

# %%
G1 = erdos_graph(80, 0.3)
plt_graph(G1)
G2 = erdos_graph(80, 0.3)
plt_graph(G2)
G3 = erdos_graph(80, 0.3)
plt_graph(G3)

# %%
import numpy as np
import networkx as nx

# %%
K = np.loadtxt('test.csv', delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %%
K = np.loadtxt('test2.csv', delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %%
K = np.loadtxt('test3.csv', delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.karate_club_graph()
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='yellow')

# %%
G.degree()
"""
key: 노드 id
value: 노드 차수
"""
# Out:
# '\nkey: 노드 id\nvalue: 노드 차수\n'

# %%
print(G.degree())
# Out:
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3), (5, 4), (6, 4), (7, 4), (8, 5), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 2), (15, 2), (16, 2), (17, 2), (18, 2), (19, 3), (20, 2), (21, 2), (22, 2), (23, 5), (24, 3), (25, 3), (26, 2), (27, 4), (28, 3), (29, 4), (30, 4), (31, 6), (32, 12), (33, 17)]

# %%
G.degree(16)
# Out:
# 2

# %%
print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
print(f'average degree: {np.mean([d for n, d in G.degree()]):.1f}')
# Out:
# number of nodes: 34
# number of edges: 78
# average degree: 4.6

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.karate_club_graph()
plt.xlabel('Degree')
plt.ylabel('probability of node degree')
plt.hist(list([d for n, d in G.degree()]), histtype='step')
# Out:
# (array([12., 12.,  3.,  2.,  0.,  2.,  1.,  0.,  0.,  2.]),
#  array([ 1. ,  2.6,  4.2,  5.8,  7.4,  9. , 10.6, 12.2, 13.8, 15.4, 17. ]),
#  [<matplotlib.patches.Polygon at 0x2938e949490>])

# %%
G = nx.karate_club_graph()
pos, degree = max([(n, d) for n, d in G.degree()])
print(f'node: {pos}')
print(f'degree: {degree}')
print(G.degree())
nx.draw(G, with_labels=True, node_size=100, node_color='yellow', edge_color='red')
# Out:
# node: 33
# degree: 17
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3), (5, 4), (6, 4), (7, 4), (8, 5), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 2), (15, 2), (16, 2), (17, 2), (18, 2), (19, 3), (20, 2), (21, 2), (22, 2), (23, 5), (24, 3), (25, 3), (26, 2), (27, 4), (28, 3), (29, 4), (30, 4), (31, 6), (32, 12), (33, 17)]

# %%
G = nx.karate_club_graph()
degree = [d for n, d in G.degree()]
nx.draw(G, with_labels=True, node_size=100, node_color='yellow', edge_color='red')

# %%
# node_size 는 명시하지 않으면 300이 기본값으로 설정되어 출력됨
nx.draw(G, with_labels=True, node_size=[n*100 for n in degree], node_color='yellow', edge_color='red')

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import zipfile

# %%
zf = zipfile.ZipFile('football.zip')
txt = zf.read('football.txt').decode()
gml = zf.read('football.gml').decode()
gml = gml.split('\n')[1:]
G = nx.parse_gml(gml)

# %%
nx.draw(G, with_labels=True, node_color='yellow', edge_color='green')
plt.savefig('football.pdf')

# %%
print(G.degree())
# Out:
# [('BrighamYoung', 12), ('FloridaState', 12), ('Iowa', 12), ('KansasState', 12), ('NewMexico', 11), ('TexasTech', 12), ('PennState', 12), ('SouthernCalifornia', 12), ('ArizonaState', 11), ('SanDiegoState', 11), ('Baylor', 10), ('NorthTexas', 10), ('NorthernIllinois', 10), ('Northwestern', 11), ('WesternMichigan', 10), ('Wisconsin', 12), ('Wyoming', 11), ('Auburn', 11), ('Akron', 11), ('VirginiaTech', 11), ('Alabama', 11), ('UCLA', 11), ('Arizona', 11), ('Utah', 11), ('ArkansasState', 10), ('NorthCarolinaState', 11), ('BallState', 10), ('Florida', 11), ('BoiseState', 9), ('BostonCollege', 11), ('WestVirginia', 11), ('BowlingGreenState', 11), ('Michigan', 11), ('Virginia', 10), ('Buffalo', 11), ('Syracuse', 11), ('CentralFlorida', 8), ('GeorgiaTech', 11), ('CentralMichigan', 11), ('Purdue', 11), ('Colorado', 11), ('ColoradoState', 10), ('Connecticut', 7), ('EasternMichigan', 11), ('EastCarolina', 11), ('Duke', 11), ('FresnoState', 11), ('OhioState', 11), ('Houston', 11), ('Rice', 11), ('Idaho', 9), ('Washington', 11), ('Kansas', 10), ('SouthernMethodist', 12), ('Kent', 10), ('Pittsburgh', 11), ('Kentucky', 10), ('Louisville', 10), ('LouisianaTech', 10), ('LouisianaMonroe', 8), ('Minnesota', 11), ('MiamiOhio', 11), ('Vanderbilt', 11), ('MiddleTennesseeState', 9), ('Illinois', 11), ('MississippiState', 11), ('Memphis', 11), ('Nevada', 12), ('Oregon', 11), ('NewMexicoState', 11), ('SouthCarolina', 11), ('Ohio', 10), ('IowaState', 11), ('SanJoseState', 11), ('Nebraska', 11), ('SouthernMississippi', 10), ('Tennessee', 11), ('Stanford', 11), ('WashingtonState', 11), ('Temple', 11), ('Navy', 11), ('TexasA&M', 11), ('NotreDame', 11), ('TexasElPaso', 11), ('Oklahoma', 11), ('Toledo', 9), ('Tulane', 11), ('Mississippi', 11), ('Tulsa', 12), ('NorthCarolina', 11), ('UtahState', 9), ('Army', 11), ('Cincinnati', 11), ('AirForce', 10), ('Rutgers', 10), ('Georgia', 10), ('LouisianaState', 10), ('LouisianaLafayette', 8), ('Texas', 11), ('Marshall', 10), ('MichiganState', 11), ('MiamiFlorida', 10), ('Missouri', 10), ('Clemson', 10), ('NevadaLasVegas', 12), ('WakeForest', 10), ('Indiana', 11), ('OklahomaState', 10), ('OregonState', 10), ('Maryland', 11), ('TexasChristian', 11), ('California', 11), ('AlabamaBirmingham', 10), ('Arkansas', 10), ('Hawaii', 11)]

# %%
zf = zipfile.ZipFile('football.zip')
txt = zf.read('football.txt').decode()
gml = zf.read('football.gml').decode()
gml = gml.split('\n')[1:]
G = nx.parse_gml(gml)

print(f'number of nodes: {G.number_of_nodes()}')
print(f'number of edges: {G.number_of_edges()}')
print(f'average of degrees: {np.mean([d for n, d in G.degree()]):.1f}')
# Out:
# number of nodes: 115
# number of edges: 613
# average of degrees: 10.7

# %%
import numpy as np
import networkx as nx

# %%
K = np.loadtxt('social.csv', delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')

# %%
ksub = nx.connected_components(G)
klist = [G.subgraph(c) for c in ksub]
# connected_components_subgraphs() 는 2.4버전에서 제거되었음
print(len(klist))
# Out:
# 2

# %%
nx.draw(klist[0], with_labels=True, node_color='yellow', edge_color='red')

# %%
nx.draw(klist[1], with_labels=True, node_color='yellow', edge_color='red')

# %%
import numpy as np
import networkx as nx

# %%
K = np.loadtxt('social.csv', delimiter=',')
G = nx.to_networkx_graph(K)
max_G = max([G.subgraph(c) for c in nx.connected_components(G)], key=len)
nx.draw(max_G, with_labels=True, node_color='yellow', edge_color='red')

# %%
K = np.loadtxt('social.csv', delimiter=',')
G = nx.to_networkx_graph(K)
min_G = min([G.subgraph(c) for c in nx.connected_components(G)], key=len)
nx.draw(min_G, with_labels=True, node_color='yellow', edge_color='red')

# %%
import numpy as np
import networkx as nx

# %%
K = np.loadtxt('social2.csv', delimiter=',')
G = nx.to_networkx_graph(K)
ksub = nx.connected_components(G)
klist = [G.subgraph(c) for c in ksub]
print(len(klist))
# Out:
# 3

# %%
print(G.degree(klist[2]))
nx.draw(klist[2], with_labels=True, node_color='yellow')
# Out:
# [(17, 3), (18, 3), (19, 3), (20, 3)]

# %%
max_G = max([G.subgraph(c) for c in nx.connected_components(G)], key=len)
nx.draw(max_G, with_labels=True, node_color='yellow', edge_color='red')
